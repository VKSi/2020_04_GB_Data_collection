# %% [markdown]
# # GeekBrains University
# ## Methods of data gathering
#
# ## Lesson 1

# %% [markdown]
# ### Task 1
# Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя,
# сохранить JSON-вывод в файле *.json.

# %%
import requests
import json
from pprint import pprint
import pandas as pd

# %%
# @hidden_cell
# headers =

# %%
user = 'idoleg'
response = requests.get(f'https://api.github.com/users/{user}/repos', headers=headers)

# %%
if response.ok:
    data = json.loads(response.text)
    with open(f'GitHub_repos_{user}.txt', 'w') as outfile:
        json.dump(data, outfile)
    for repo in data:
        print(repo['name'])
# Out:
# atol-web-service
# cdn-player
# docker-nginx-certbot
# epub-test
# flux-test
# gamedude
# gb-forum-html
# gbtools
# hackathon-ls
# iziModal
# javascript-tutorial
# jwt-auth
# laravel-postgres-ext
# messenger-backend
# messenger-backend-python
# node-getenv
# phaser-minesweeper
# react-03.03
# react-14.01
# react-29.11
# test-task-hero
# ts-project-skeleton

# %% [markdown]
# ### Task 2
# Изучить список открытых API. Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %% [markdown]
# https://developer.foursquare.com/docs/

# %%
# @hidden_cell
# CLIENT_ID = '' # my Foursquare ID
# CLIENT_SECRET = '' # my Foursquare Secret
# headers = {'User-Agent':
    ''}

# %%
main_link = 'https://api.foursquare.com/v2/venues/explore' \

params = {'client_id':CLIENT_ID,
            'client_secret':CLIENT_SECRET,
            'v':"20180323",
            'll':"61.666668, 50.816666", # Syktyvkar
            'query':"restaurant",
            'limit':10}

# %%
response = requests.get(main_link,headers=headers,params=params)

# %%
if response.ok:
    data = json.loads(response.text)
    pprint(data)
# Out:
# {'meta': {'code': 200, 'requestId': '5e8c736040a7ea001c1a9bf6'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#                                                  'items': [{'reasonName': 'globalInteractionReason',
#                                                             'summary': 'This '
#                                                                        'spot '
#                                                                        'is '
#                                                                        'popular',
#                                                             'type': 'general'}]},
#                                      'referralId': 'e-0-4e493f031f6e29f10dc9a71b-0',
#                                      'venue': {'beenHere': {'count': 0,
#                                                             'lastCheckinExpiredAt': 0,
#                                                             'marked': False,
# ...

# %%
data = data["response"]['groups'][0]['items']
pprint(data)
# Out:
# [{'reasons': {'count': 0,
#               'items': [{'reasonName': 'globalInteractionReason',
#                          'summary': 'This spot is popular',
#                          'type': 'general'}]},
#   'referralId': 'e-0-4e493f031f6e29f10dc9a71b-0',
#   'venue': {'beenHere': {'count': 0,
#                          'lastCheckinExpiredAt': 0,
#                          'marked': False,
#                          'unconfirmedCount': 0},
#             'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#                                      'suffix': '.png'},
#                             'id': '4bf58dd8d48988d1ca941735',
#                             'name': 'Pizza Place',
#                             'pluralName': 'Pizza Places',
#                             'primary': True,
#                             'shortName': 'Pizza'}],
#             'contact': {},
#             'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'},
# ...

# %%
venues_list=[]
venues_list.append([(
    v['venue']['name'], 
    v['venue']['location']['lat'], 
    v['venue']['location']['lng'],  
    v['venue']['categories'][0]['name']) for v in data])


df = pd.DataFrame(venues_list[0])
df.columns = ['Venue', 
              'Venue Latitude', 
              'Venue Longitude', 
              'Venue Category']

df
# Out:
#                Venue  Venue Latitude  Venue Longitude  \
# 0         Додо Пицца       61.665549        50.832212
# 1         Фрау Марта       61.659741        50.833370
# 2         Frau Marta       61.659693        50.833580
# 3          Cafeshion       61.662297        50.809398
# 4  Додо Пицца & Кофе       61.663835        50.817320
# 5          ШашлыкOFF       61.675255        50.823372
# 6           Комильфо       61.668470        50.827096
# 7             Гранат       61.668748        50.830246
# 8             Бублик       61.675644        50.823075
# 9                Ани       61.675134        50.841229
#
#                 Venue Category
# 0                  Pizza Place
# 1            German Restaurant
# 2            German Restaurant
# 3                         Café
# 4                  Pizza Place
# 5                    BBQ Joint
# 6  Eastern European Restaurant
# 7         Caucasian Restaurant
# 8                   Restaurant
# 9    Middle Eastern Restaurant
